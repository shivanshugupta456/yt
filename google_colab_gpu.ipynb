# %% [markdown]
# # Google Colab GPU Setup for Streamlit Text-to-Video
#
# Use this notebook to run the Streamlit app on Google Colab with GPU. You can either clone the repo from GitHub or mount your Google Drive if the repo is already there.

# %% [markdown]
# ## Option 1: Clone from GitHub
#
# If your repo is on GitHub, update the URL below and run the cell.

# %%
# Clone your GitHub repository (update the URL)
# !git clone https://github.com/YOUR_USERNAME/YOUR_REPO.git /content/generative-ai
# %cd /content/generative-ai

# %% [markdown]
# ## Option 2: Mount Google Drive
#
# If you have the repo in your Google Drive, mount Drive and copy it locally.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Update the source path to your repo location in Drive
# !cp -r '/content/drive/MyDrive/Generative ai' /content/generative-ai
# %cd /content/generative-ai

# %% [markdown]
# ## Install dependencies
#
# Install the Python packages required to run the Streamlit app.

# %%
# Install GPU-compatible PyTorch if needed",
